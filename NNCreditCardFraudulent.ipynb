# %% [markdown]
# <a href="https://colab.research.google.com/github/trupti2021/FirstGIT/blob/main/NNCreditCardFraudulent.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install tensorflow

# %%
from tensorflow.keras import layers
from tensorflow.keras import models
import pandas as pd

# %%
df=pd.read_csv("/content/drive/MyDrive/AutogluonDrop/fraud_sample.csv")

# %%
df
# Out:
#     Transaction_Amount  Transaction_Time Merchant_Category  Customer_Age  \
# 0              1872.34                14           Grocery            45
# 1              4321.10                 2            Online            29
# 2               120.55                10              Fuel            52
# 3              3050.75                 1            Online            34
# 4                89.99                18        Restaurant            41
# 5               560.20                20           Grocery            38
# 6              2750.00                 3            Travel            30
# 7                45.60                12              Fuel            55
# 8              3999.99                23            Online            27
# 9               150.00                 9        Restaurant            48
# 10             2200.45                 4            Online            36
# 11               75.25                16           Grocery            60
# ...

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
df['Merchant_Category']=le.fit_transform(df['Merchant_Category'])
df
# Out:
#     Transaction_Amount  Transaction_Time  Merchant_Category  Customer_Age  \
# 0              1872.34                14                  1            45
# 1              4321.10                 2                  2            29
# 2               120.55                10                  0            52
# 3              3050.75                 1                  2            34
# 4                89.99                18                  3            41
# 5               560.20                20                  1            38
# 6              2750.00                 3                  4            30
# 7                45.60                12                  0            55
# 8              3999.99                23                  2            27
# 9               150.00                 9                  3            48
# 10             2200.45                 4                  2            36
# 11               75.25                16                  1            60
# ...

# %%
import numpy as np
impo
