# %% [markdown]
# <a href="https://colab.research.google.com/github/trupti2021/FirstGIT/blob/main/BronzeAssignmentMatc26.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Bronze assignment
#EMployee Productivity Core to imrove workforce planning
#muktivariance Linesar regression model that predict employee productivity score based on multi factor

#Experice  Training hrs, working hrs, project     Productivity score

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('/content/drive/MyDrive/AutogluonDrop/employee_productivity_dataset.csv')

# %%
import sklearn

# %%
from sklearn.linear_model import LinearRegression

# %%
df
# Out:
#     employee_id  experience_years  training_hours  working_hours_per_week  \
# 0          E001                 1              20                      39
# 1          E002                 2              25                      40
# 2          E003                 3              30                      41
# 3          E004                 4              35                      42
# 4          E005                 5              40                      38
# ..          ...               ...             ...                     ...
# 115        E116                 6              56                      40
# 116        E117                 7              61                      41
# 117        E118                 8              66                      42
# 118        E119                 9              71                      43
# 119        E120                10              76                      39
#
#      num_projects  productivity_score
# 0               1                57.0
# ...

# %%
import math
math.floor(df.experience_years.median())
# Out:
# 5

# %%
from sklearn.linear_model import LinearRegression
modle=LinearRegression()

# %%
X=df[['experience_years','training_hours','working_hours_per_week','num_projects']]
y=df['productivity_score']
modle.fit(X,y)
# Out:
# LinearRegression()

# %%
modle.predict([[1,20,39,1]]		)
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([57.])

# %%
import matplotlib.pyplot as plt

# %%
columns=['experience_years','training_hours','working_hours_per_week','num_projects']
for col in columns:
   plt.figure()
  #plt.scatter(df[col],df['productivity_score'])
   plt.scatter(df[col], df["productivity_score"])
   plt.xlabel=col
   plt.ylabel='productivity_score'
   plt.show()
   plt.title(f"{col} vs productivty score")
