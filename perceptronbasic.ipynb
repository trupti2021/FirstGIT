# %% [markdown]
# <a href="https://colab.research.google.com/github/trupti2021/FirstGIT/blob/main/perceptronbasic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df=pd.read_csv("https://raw.githubusercontent.com/campusx-official/100-days-of-deep-learning/main/day3/placement.csv")
df
# Out:
#     cgpa  resume_score  placed
# 0   8.14          6.52       1
# 1   6.17          5.17       0
# 2   8.27          8.86       1
# 3   6.88          7.27       1
# 4   7.52          7.30       1
# ..   ...           ...     ...
# 95  6.33          6.38       0
# 96  8.23          7.76       1
# 97  6.65          7.78       0
# 98  8.14          5.63       1
# 99  6.09          6.61       0
#
# [100 rows x 3 columns]

# %%
import seaborn as sns

# %%
sns.scatterplot(x=df['cgpa'],y=df['resume_score'],hue=df['placed'])
#
# Out:
# <Axes: xlabel='cgpa', ylabel='resume_score'>

# %%
X=df.iloc[:,0:2]
y=df.iloc[:,-1]

# %%
X
y
# Out:
# 0     1
# 1     0
# 2     1
# 3     1
# 4     1
#      ..
# 95    0
# 96    1
# 97    0
# 98    1
# 99    0
# Name: placed, Length: 100, dtype: int64

# %%
from sklearn.linear_model import Perceptron
p1=Perceptron()

# %%
p1.fit()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_1087/2260460544.py in <cell line: 0>()
# ----> 1 p1.fit()
#
# /usr/local/lib/python3.12/dist-packages/sklearn/base.py in wrapper(estimator, *args, **kwargs)
#    1387                 )
#    1388             ):
# -> 1389                 return fit_method(estimator, *args, **kwargs)
#    1390
#    1391         return wrapper
#
# TypeError: BaseSGDClassifier.fit() missing 2 required positional arguments: 'X' and 'y'
